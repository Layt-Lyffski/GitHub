# %% [markdown]
# ### Nullprodukt - Nullstelle
# Ein Produkt ist genau dann gleich Null, wenn einer der Faktoren Null ist.
#
#
# Diesen Satz vom Nullprodukt kannst du häufig bei der Berechnung von Nullstellen, Extremstellen oder Wendestellen nutzen.
#
# Um $x^4+3x^3=0$ zu lösen, wird zunächst $x^3$ ausgeklammert:
# \begin{align}x^3(x+3)=0 => x^3=0\quad\text{oder}\quad x+3=0.\end{align}
# Damit sind die Lösungen: $x_1=0$ und $x_2=-3$.

# %% [markdown]
# ### Substitution - Nullstelle
# Wenn in einer Gleichun lediglich __gerade Potenzen von x__ auftreten, kann eine __Substitution__ druchgeführt werden.
# <br>
#
# $$x^4 - 5x^2 = 36$$
# Schritt 1: Bringe alles auf eine Seite
# $$x^4 - 5x^2-36 = 0$$
# Schritt 2: Substitution: Setze u=x^2, dann gilt:
# $$u^2 - 5u - 36 = 0$$
# Schritt 3: Löse die Gleichung (mit nullstellen für 2.Polynom)
# $$u_{1,2}= \frac{5}{2}\pm \sqrt{\frac{25}{4}+36} => u_1 = 9, u_2 = -4$$
# Schritt 4: Rücksubstitution (in u gleichung): Löse x^2=u Mathe-Abitur, also:
# $$u_1 = 9: x^2 = 9 \iff x_1 = 3, x_2 = -3$$
# $$u_2 = -4: x^2 = -4 => \text{keine weiteren Lösungen}$$
# Es folgt also $\mathbb{L} = {-3;3}$
# <br>
# <br>

# %% [markdown]
# ### Polynomdivision - Nullstelle
# Für eine ganzrationale Funktion $f$ gilt:
# <br>
# Ist $x=a$ eine Nullstelle von $f$, so ist das Ergebnis der Polynomdivision wieder eine ganzrationale Funktion, heitß:
# \begin{align}f(x):(x-a)\end{align}
# <br>
# Die Nullstellen dieses Ergebnisses zusammen mit $x=a$ sind die Nullstellen von $f$.
# Häufig muss die erste Nullstelle x=a Mathe-Abitur geraten werden.
# <br>
# Man untersucht dabei zunächst die (positiven und negativen) Teiler des Absolutglieds von $f$, also der Zahl ohne die Variable $x$.
# <br><br>
# Bestimme die Nullstellen der Funktion $f$  mit
# \begin{align}f(x)=x^3-6x^2+11x-6.\end{align}
# Gesucht sind also die Lösungen der Gleichung
# \begin{align}x^3-6x^2+11x-6=0.\end{align}
# Hier helfen weder der Satz vom Nullprodukt noch Substitution weiter. Daher muss eine erste Nullstelle geraten werden.
#
# Das Absolutglied ist $6$. Die Menge der Teiler von $6$ ist gegeben durch ${\pm 1; \pm 2; \pm 3; \pm 6}$
# Man bestimmt nun von jedem dieser Teiler den Funktionswert $f(x)$, bis man als Ergebnis 0 erhält.
#
# Setzt man zum Beispiel $x=1$ ein, so erhält man:
# \begin{align}f(1)=1^3-6\cdot 1^2 +11\cdot 1 - 6 = 0. \end{align}
# Das Ergebnis der Polynomdivision $f(x):(x-1)$ ist also wieder eine ganzrationale Funktion.
# Es gilt:
# <br>
# ![image-2.png](attachment:image-2.png)
# <br>
# Das Ergebnis ist $g(x)=x^2-5x+6$. Die Funktion $g$ wird nun auf Nullstellen untersucht. Dabei erhält man mit der $p-q$-Formel bzw. Mitternachtsformel:
# \begin{align}x_2=2\quad \text{und} \quad x_3=3.\end{align}
# Somit sind die Nullstellen der Funktion $f$ gegeben durch:
# \begin{align}\mathbb{L}=\{1; 2; 3\}.\end{align}

# %% [markdown]
# ### Newtonsches Näherungsverfahren - Nullstelle
# Gegeben ist die Funktion $f$ durch $f(x)=x^3+5x-7$. Gesucht ist die Nullstelle der Funktion $f$ im Intervall $[0;3]$ mit einer Genauigkeit von zwei Nachkommastellen.
#
# __Schritt 1:__ Fertige eine Wertetabelle an: Je nach Intervallgröße kannst du hierbei ganze Zahlen verwenden oder in kleineren Schritten vorgehen:
#
# |x   |0   |1   |2   |3   |
# |---|---|---|---|---|
# |f(x)   |-7   |-1   |11   |35   |
#
# __Schritt 2:__ Wähle einen geeigneten Startwert. Wähle einen geeigneten Startwert $x_0$ für das Näherungsverfahren, optimalerweise bereits nahe der Nullstelle, zum Beispiel:
#     \begin{align}x_0=1.\end{align}
#
# __Schritt 3:__ Bestimme eine Tangentengleichung und deren Nullstelle. Bestimme die Gleichung der Tangente an den Graphen der Funktion $f$ an der Stelle $x_0$ und bestimme deren Nullstelle $x_1$. Diese Nullstelle ist dann die Näherung im ersten Schritt:
#
# \begin{align}t_0(x)=f'(x_0)\cdot(x-x_0)+f(x_0),\end{align}
#    also:
#    \begin{align}t_0(x_1)=0 \iff x_1=x_0-\frac{f(x_0)}{f'(x_0)}\\x_1=1-\frac{-1}{8}=\frac{9}{8}=1,12... \end{align}
#
# __Schritt 4:__ Verfahre nun mit der Stelle $x_1$ genauso wie gerade eben mit der Stelle $x_0$, um $x_2$ zu erhalten, also
#     \begin{align}x_2=x_1-\frac{f(x_1)}{f'(x_1)}=1,125-\frac{0,049}{8,797}=1,119.\end{align}
# __Schritt 5:__ Erstelle eine Tabelle mit den einzelnen Näherungswerten. Insgesamt gilt für die einzelnen Schritte
#
# |$x_0$| $x_1$   |$x_2$   |...   |
# |---|---|---|---|
# |1.0   |1.119   |1.119   |...   |
#
#
# Hier kann man direkt erkennen, dass sich die dritte Nachkommastelle bereits ab $x_2$ nicht mehr ändert. Eine Näherung der Nullstelle mit der geforderten Genauigkeit (zwei Nachkommastellen) lautet also:
#     \begin{align}x^*=1,12.\end{align}
#     Durch die vorangegangene Wertetabelle wurde der Startwert so gut gewählt, dass nur wenige Iterationsschritte nötig waren.
#     Beachte, dass das Newton-Verfahren abbricht, falls bei einem Interationsschritt die Tangente waagrecht ist. Dann muss ein neuer, geeigneterer Startwert gefunden werden.

# %% [markdown]
#  ### Wurzelgleichungen - Gleichungen
# Ein Wurzelausdruck ist nur definiert, wenn der Term unter der Wurzel, auch Radikand genannt, größer oder gleich 0 ist.
#
# Der Ausdruck
# \begin{align}\sqrt{9-x^2}\end{align}
# ist nur für $-3\leq x \leq 3$ definiert.
# An den Stellen $x=-3$ bzw. $x=3$ ist der Ausdruck gleich 0.
#
# Finde alle Lösungen der Gleichung
# \begin{align}\sqrt{4x+16}+x+1=0. \end{align} Mathe-Abitur
#
#    Schritt 1: Isoliere die Wurzel:
#     \begin{align}\sqrt{4x+16}=-x-1\end{align} Mathe-Abitur
#     Schritt 2: Quadriere beide Seiten und beachte dabei die binomischen Formeln:
#     \begin{align}4x+16=(-x-1)^2=x^2+2x+1\end{align} Mathe-Abitur
#     Schritt 3: Löse die entstehende Gleichung mit der p Mathe-Abitur-q Mathe-Abitur-Formel / Mitternachtsformel:
#     \begin{align}x^2-2x-15=0 \quad \text{also} \quad x_1=-3 \quad \text{oder} \quad x_2=5\end{align} Mathe-Abitur
#     Schritt 4: Mit den gefundenen Lösungen eine Probe machen, denn durch das quadrieren können Lösungen dazugekommen sein:
# \begin{alignat}{3}x_1=-3: \sqrt{4\cdot(-3)+16}-3+1 = 2-3+1 = 0 => True \\x_2=5 : \sqrt{4\cdot(5)+16}+5+1 = 6+5+1=12 => False  \end{alignat}...
# Also gilt: $L=\{-3\}$.

# %% [markdown]
# # Exponentialgleichungen - Gleichungen
# Drei Typen von Exponentialgleichung __es gilt $e^t > 0$ und falls $e^t = -1$ dann keine Lösung, heitß: $\mathbb{L} =$ {}__
# <br>
#    __Typ 1:__ Alle Exponential-Terme haben den gleichen Exponenten, zum Beispiel:
#     \begin{align}e^{3x-1} +2= 4-e^{3x-1}.\end{align}
#     __Typ 2:__ Es treten verschiedene Exponenten auf, aber dafür keine Zahlen, zum Beispiel:
#     \begin{align}3e^{2x}-4e^{5x}=0.\end{align}
#     __Typ 3:__ Es treten verschiedene Exponenten und auch Zahlen auf, zum Beispiel:
#     \begin{align}e^{2x}-5e^{x}=36.\end{align}
#     <br>
#     <br>
# ---
#  __(Typ 1)__ Bestimme die Lösungen der Gleichung
# \begin{align}5e^{2x+1}-3=3e^{2x+1}+1.\end{align}
#
#    __Schritt 1:__ Isoliere den Exponentialterm:
#     \begin{align}5e^{2x+1}-3=3e^{2x+1}+1\\\iff 2e^{2x+1}=4\\\iff e^{2x+1}=2.\end{align}
#
#    __Schritt 2:__ Logarithmiere beiden Seiten:
#     \begin{align}\ln\left(e^{2x+1}\right)=\ln(2) \iff 2x+1=\ln(2).\end{align}
#
#   __Schritt 3:__ Löse nach $x$ auf:
#     \begin{align}x=\frac{\ln(2)-1}{2}.\end{align}
# <br>
# <br>
# ---
# __(Typ 2)__ Bestimme die Lösungen der Gleichung $$4e^{3x}=2e^{5x}$$
#
#    __Schritt 1__ Bringe alles auf eine Seite:
#     \begin{align}2e^{5x}-4e^{3x}=0.\end{align}
#     __Schritt 2:__ Klammere die kleinste $e$-Potenz aus und beachte dabei die Potenzgesetze:
#     \begin{align}e^{3x}\left(2e^{2x}-4\right)=0.\end{align}
#     __Schritt 3:__ Wende den Satz vom Nullprodukt an:
#     \begin{align}e^{3x}= 0 \quad \text{oder} \quad 2e^{2x}-4=0.\end{align}
#     Die Gleichung $e^{3x}= 0$ besitzt keine Lösung.
#     __Schritt 4:__ Bestimme die Lösungsmenge der zweiten Gleichung:
#     \begin{align}2e^{2x}-4=0 \iff e^{2x}=2 \\\iff x=\frac{1}{2}\ln(2).\end{align}
#
# <br>
# <br>
#
# ---
#
# __(Typ 3)__ Bestimme die Lösungen der Gleichung$$e^{2x}+e^{x}=6$$
#
#    __Schritt 1:__ Bringe alles auf eine Seite:
#     \begin{align}e^{2x}+e^x-6=0.\end{align}
#     __Schritt 2:__ Substitution: Setze u=\e^x:
#     \begin{align}u^2+u-6=0.\end{align}
#     __Schritt 3:__ Löse die entstandene Gleichung mit der Lösungsformel für quadratische Gleichungen:
#     \begin{align}u_{1,2}=\frac{-1\pm\sqrt{1+24}}{2} => u_1=2, \quad u_2=-3.\end{align}
#     __Schritt 4:__ Rücksubstitution: Löse $e^x=u$:
#     \begin{align}u_1=2:\quad e^x=2 => x=\ln(2) \\u_2=-3:\quad e^x=-3 => \text{keine weiter Lösungen} \end{align}
#     Es folgt also $\mathbb{L}=\{\ln(2)\}$
